# %%
from scipy.sparse import csc_array
from scipy.sparse.linalg import bicgstab
from scipy.sparse.linalg import cg
from scipy.sparse.linalg import gmres
import numpy as np
import matplotlib.pyplot as plt
pi = np.pi

# %%
def DatosMat(path):
    data = [[],[],[],[]]
    with open(path) as fobj:
        for i, line in enumerate(fobj):
           # data.append([])
            if line.rsplit() != []:
                row = line.rsplit()   
                for j in range(len(row)):
                    data[j].append(float(row[j]))     
    return data

def DatosVec(path):
    data = [[],[],[]]
    with open(path) as fobj:
        for i, line in enumerate(fobj):
           # data.append([])
            if line.rsplit() != []:
                row = line.rsplit()   
                for j in range(len(row)):
                    data[j].append(float(row[j]))     
    return data

# %%
Nx, Nt = 8, 8
block_x, block_t = 2, 2
x_elements, t_elements = int(Nx/block_x), int(Nt/block_t)
Ntest, Nagg = 5, 2*(block_x*block_t)
Ntot = Nx*Nt
Coords = np.zeros((Nx,Nt,2),dtype=int)
for x in range(Nx):
    for t in range(Nt):
        for s in range(2):
            Coords[x,t,s] = x * Nt * 2 + t * 2 + s
XCoord = np.zeros(2*Nx*Nt,dtype=int)
TCoord = np.zeros(2*Nx*Nt,dtype=int)
SCoord = np.zeros(2*Nx*Nt,dtype=int)
Agg = np.zeros((2*block_x*block_t,x_elements*t_elements),dtype=int)
print("Lattice dimensions Nx={0}, Nt={1}".format(Nx,Nt))
print("Number of aggregates {0}".format(Nagg))
print("Block_x={0}, Block_t={1}".format(block_x,block_t))
print("Number of test vectors {0}".format(Ntest))
# Out:
# Lattice dimensions Nx=8, Nt=8
# Number of aggregates 8
# Block_x=2, Block_t=2
# Number of test vectors 5

# %%
#Computing the aggregates
for x in range(block_x):
    for t in range(block_t):
        for s in range(2):
            x0, t0 = x * x_elements, t * t_elements
            x1, t1 = (x+1) * x_elements, (t+1) * t_elements
            aggregate = x * block_t * 2 + t * 2 + s
            count = 0
            for X in range(x0,x1):
                for T in range(t0,t1):
                    i = X * Nt * 2 + T * 2 + s
                    XCoord[i] , TCoord[i], SCoord[i] = X, T, s
                    Agg[aggregate][count] = i
                    count += 1

# %%
class AMG():
    def __init__(self,D,nu1,nu2):
        self.test_vectors = np.zeros((Ntest,2*Ntot),dtype=complex) 
        self.P = np.zeros((2*Ntot,Ntest*Nagg),dtype=complex) 
        self.PH = np.zeros((Ntest*Nagg,2*Ntot),dtype=complex) 
        self.D = csc_array(D) #Dirac matrix
        self.Dc = np.zeros((Ntest*Nagg,Ntest*Nagg),dtype=complex) 
        self.nu1 = nu1
        self.nu2 = nu2
        self.it = 0 #Parameter to measure iterations for convergence

    def get_p(self):
        return self.P, self.PH
    def get_Dc(self):
        return self.Dc
    def get_iterations(self):
        return self.it

    def orthonormalize(self):
        v_chopped = [] #Columns of the interpolator
        for i in range(Ntest*Nagg):
            v = np.eye(1,Ntest*Nagg,i).reshape(Ntest*Nagg)
            v_chopped.append(self.P @ v)
        v_chopped = np.array(v_chopped)        
        for i in range(Nagg):
            for nt in range(Ntest):
                for j in range(nt):
                    #vdot(a,b) = a* . b /= b* . a = vdot(b,a)
                    proj = np.vdot(v_chopped[j * Nagg + i],v_chopped[nt * Nagg + i])
                    v_chopped[nt * Nagg + i] -= proj * v_chopped[j * Nagg + i]
                v_chopped[nt*Nagg+i] /= np.linalg.norm(v_chopped[nt*Nagg+i])
        matrix =  np.zeros((2*Ntot,Ntest*Nagg),dtype=complex) 
        for i in range(Ntest*Nagg):
            matrix[:,i] = v_chopped[i]
        self.P = matrix
        self.PH = csc_array(np.conjugate(np.transpose(self.P)))
        self.P = csc_array(self.P)
        self.Dc = (self.PH @(self.D @ self.P)) #matrix multiplication

    def tv(self,Nit):  
        test_vectors_copy = np.zeros((Ntest,2*Ntot),dtype=complex) 
        for i in range(Ntest): 
            for j in range(2*Ntot):
                theta = np.random.uniform(0,2*pi)
                self.test_vectors[i,j] = np.cos(theta) + 1j*np.sin(theta)
        for i in range(Ntest):
            self.test_vectors[i], exit_code = gmres(self.D, self.test_vectors[i], x0=self.test_vectors[i] ,maxiter=20)
        self.P_v() #Assemble P
        self.orthonormalize() #Orthonormalize
        print("Improving interpolator")
        for n in range(Nit):
            print("n={0} out of Nit={1}".format(n,Nit))
            for i in range(Ntest):
                self.test_vectors[i] = self.TwoGrid(1,1e-10,self.test_vectors[i],self.test_vectors[i],False)
            self.P_v() #Assemble P
            self.orthonormalize() #Orthonormalize
            
             
    def P_v(self):
        #Assembling the interpolator
        for can_vec in range(Ntest*Nagg):   
            P_v = np.zeros(2*Ntot,dtype=complex)
            v = np.eye(1,Ntest*Nagg,can_vec).reshape(Ntest*Nagg)
            for j in range(Ntest*Nagg):
                k = int(j / Nagg)
                a = int(j % Nagg)
                for i in range(len(Agg[a])):
                    x, t, s = XCoord[Agg[a,i]], TCoord[Agg[a,i]], SCoord[Agg[a,i]]
                    P_v[Coords[x,t,s]]  += self.test_vectors[k,Coords[x,t,s]] * v[j]
            self.P[:,can_vec] = P_v   
        self.PH = csc_array(np.conjugate(np.transpose(self.P)))
        self.P = csc_array(self.P)
        self.Dc = (self.PH @(self.D @ self.P)) #matrix multiplication
        
    def TwoGrid(self,max_iter,tol,x0,phi,message):
        #Solve D x = phi
        x = x0
        err = 1
        k = 0
        r0 = phi - self.D.dot(x)
        max_err = tol*np.linalg.norm(phi)
        while(k < max_iter and err > max_err):
            if self.nu1 > 0:
                x, exitCode = gmres(self.D, phi, x0=x , tol=1e-10, atol=0.0, maxiter=nu1) 
            #Coarse grid correction
            Pt_r = self.PH.dot( (phi-self.D.dot(x)))
            Dc_inv, exit_code = bicgstab(self.Dc, Pt_r,x0=Pt_r,maxiter=10000, tol=1e-10, atol=0.0) #Dc^-1 P^H(phi-Dx)
            if message==True:
                if exit_code == 0:
                    print("Bi-cgstab converged for Dc")
                else:
                    print("Bi-cgstab did NOT converge for Dc")
            x += self.P.dot(Dc_inv)
            if self.nu2>0:
                x, exitCode = gmres(self.D, phi, x0=x ,tol=1e-10, atol=0.0, maxiter=nu2)
            r = phi - self.D.dot(x)
            err = np.sqrt(np.real(np.vdot(r,r))) #complex dot product
            if message == True:
                print("iteration",k,"error",err)
            if err<=max_err:
                self.it = k+1
                print("two-grid converged in",k+1,"iterations. Error ",err)
                return x
            k+=1
        if message == True:
            print("two-grid did not converge in",max_iter,"iterations. Error ",err)
        self.it = max_iter
        return x

    def print_p(self):
        for i in range(2*Ntot):
            for j in range(Ntest*Nagg):
                print(self.P[i,j], end = " ")
            print('')

# %%
dim = Nx*Nt*2
print(dim)
D = np.zeros((dim,dim),dtype=complex)
row, col, re, im = DatosMat("build/D36.dat")
for i in range(dim*dim):
    D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
phi = np.zeros(dim,dtype=complex)
row, col, re, im = DatosMat("build/phi36.dat")
for i in range(dim):
    phi[i] = re[i] + 1j*im[i]
# Out:
# 128

# %%
#Initial solution
x0 = np.zeros(2*Ntot,dtype=complex)
for i in range(2*Ntot):  
    theta = np.random.uniform(0,2*pi)
    x0[i] = np.cos(theta) + 1j*np.sin(theta)

# %%
Dsparse = csc_array(D)
x_gmres = x0
#GMRES
tol = 1e-10
print("---GMRES---")
for i in range(1000):
    x_gmres, exit_code = gmres(Dsparse, phi, x0=x_gmres, tol=1e-10, atol=0.0, maxiter=1)
    r = phi - Dsparse.dot(x_gmres)
    err = np.sqrt(np.real(np.vdot(r,r)))
    print(i,err,exit_code)
    if err<=tol*np.linalg.norm(phi):
        print("GMRES converged in {0} iterations".format(i+1))
        break
#bi-cgstab
print("---Bi-cgstab---")
x_bi = x0
x_bi, exit_code = bicgstab(Dsparse, phi,x0=x_bi,maxiter=500, tol=1e-10)
if exit_code == 0:
    print("Converged")
else:
    print("Did not converge")
r = phi - Dsparse.dot(x_bi)
err = np.sqrt(np.real(np.vdot(r,r)))
print("Bi-cgstab error {0}".format(err))
# Out:
# ---GMRES---
# 0 4.041879487629367 1
# 1 3.2772304610238083 1
# 2 2.5697510035409525 1
# 3 2.230988670017254 1
# 4 2.1050599465240514 1
# 5 2.024298987733361 1
# 6 1.9596151585141197 1
# 7 1.8943118862793757 1
# 8 1.8260411571063249 1
# 9 1.756889565109724 1
# 10 1.68584626882154 1
# 11 1.631279563296856 1
# 12 1.5817301814775855 1
# 13 1.5353461196466631 1
# 14 1.4838766757733999 1
# 15 1.4279573724435566 1
# 16 1.3688444859025997 1
# 17 1.329616475540076 1
# 18 1.3081162454042259 1
# 19 1.292455389321972 1
# 20 1.2739434287011107 1
# 21 1.2479169671844705 1
# 22 1.225694825635712 1
# 23 1.2086718670858874 1
# 24 1.1945503372102952 1
# 25 1.1866111814521743 1
# 26 1.180340133313093 1
# 27 1.175300412424421 1
# 28 1.16974636946447 1
# 29 1.1626744039675747 1
# 30 1.1528635166552497 1
# 31 1.1376903895012564 1
# 32 1.1157462411334669 1
# 33 1.073076312040016 1
# 34 1.0245093347149132 1
# 35 0.9845978565803516 1
# 36 0.9413187710410018 1
# 37 0.92205961624591 1
# 38 0.9131759028726956 1
# 39 0.9067545552324834 1
# 40 0.9008456380242484 1
# 41 0.8936576899692509 1
# 42 0.8836512672801233 1
# 43 0.8688378295634482 1
# 44 0.8485248123348313 1
# 45 0.8228049510312219 1
# 46 0.793607754327084 1
# 47 0.7674620139235089 1
# 48 0.7454695991740513 1
# 49 0.7324323724568861 1
# 50 0.7221361599511341 1
# 51 0.7099645217490369 1
# 52 0.6929766663199243 1
# 53 0.6727161573331055 1
# 54 0.6528057475419335 1
# 55 0.6357883787863647 1
# 56 0.622099196736908 1
# 57 0.6098474600396159 1
# 58 0.5980522681878726 1
# 59 0.5857994756710897 1
# 60 0.5721658621689291 1
# 61 0.5543350165342147 1
# 62 0.5293777963614194 1
# 63 0.5101852783406948 1
# 64 0.4988903302134289 1
# 65 0.4898672619006399 1
# 66 0.48475659818831296 1
# 67 0.48100521578653405 1
# 68 0.4777135802437509 1
# 69 0.4740545899344157 1
# 70 0.46907745991378746 1
# 71 0.46095637937370654 1
# 72 0.44977479115439856 1
# 73 0.43700667708136376 1
# 74 0.42485873132866175 1
# 75 0.41455987665862537 1
# 76 0.39944968585306007 1
# 77 0.3891130436726419 1
# 78 0.38578483072050535 1
# 79 0.38306972129240396 1
# 80 0.37940566366226647 1
# 81 0.36438737043959235 1
# 82 0.2974476622060814 1
# 83 0.23434706546955403 1
# 84 0.20692546475281726 1
# 85 0.18771141457285748 1
# 86 0.17345551266919723 1
# 87 0.16362602317268343 1
# 88 0.15885500803544153 1
# 89 0.15581831031406923 1
# 90 0.15320991557300606 1
# 91 0.150332144158786 1
# 92 0.14690563397701759 1
# 93 0.14316475104911858 1
# 94 0.13937134194166403 1
# 95 0.13504000456177587 1
# 96 0.13181726171622213 1
# 97 0.1296912214224178 1
# 98 0.12359434479183039 1
# 99 0.11637874175823752 1
# 100 0.11378949650804898 1
# 101 0.11132399181188997 1
# 102 0.10844864634370069 1
# 103 0.10568116298414826 1
# 104 0.10317341883926005 1
# 105 0.10007385644788935 1
# 106 0.09697870486552071 1
# 107 0.09469162774192987 1
# 108 0.09248466038445911 1
# 109 0.08978714466446147 1
# 110 0.08708029476072113 1
# 111 0.08387228205297764 1
# 112 0.07953452326750894 1
# 113 0.07430293672083703 1
# 114 0.06897108512344301 1
# 115 0.06460645733703158 1
# 116 0.061098594252382336 1
# 117 0.05804705553796773 1
# 118 0.055133739096143546 1
# 119 0.052017362860529555 1
# 120 0.04806777548609794 1
# 121 0.0433806344976343 1
# 122 0.03996831604432471 1
# 123 0.03775129424035024 1
# 124 0.03571024175071339 1
# 125 0.03345274935039226 1
# 126 0.031571682984284304 1
# 127 0.030286411584251282 1
# 128 0.02935706185596129 1
# 129 0.028563582769896855 1
# 130 0.027722880646150326 1
# 131 0.026683464452857932 1
# 132 0.025442491199331504 1
# 133 0.024131307212318733 1
# 134 0.02302959160006244 1
# 135 0.022164357270997154 1
# 136 0.021384477655696923 1
# 137 0.02057681559322856 1
# 138 0.01943789310244099 1
# 139 0.017976465680070504 1
# 140 0.016740081688592128 1
# 141 0.01567090156237507 1
# 142 0.0148015748194216 1
# 143 0.01403216398222689 1
# 144 0.013539385604278675 1
# 145 0.013199325885322378 1
# 146 0.012900449332663296 1
# 147 0.012761747855867618 1
# 148 0.012632676534708788 1
# 149 0.012382979606943241 1
# 150 0.01215952304283464 1
# 151 0.011966744833839485 1
# 152 0.011690749304507149 1
# 153 0.011310087169023503 1
# 154 0.010839898298131733 1
# 155 0.010375690046800739 1
# 156 0.00997711742758369 1
# 157 0.009639476205508504 1
# 158 0.009325012185878551 1
# 159 0.008945487071038172 1
# 160 0.00869096604444736 1
# 161 0.008540864924810664 1
# 162 0.008367156961424453 1
# 163 0.008110453979027264 1
# 164 0.007687009929375789 1
# 165 0.007231747356298199 1
# 166 0.006754625431360722 1
# 167 0.00626908593520045 1
# 168 0.0057654438484012315 1
# 169 0.005233780072662988 1
# 170 0.00449989168281082 1
# 171 0.0036376088121664973 1
# 172 0.002716164641271962 1
# 173 0.0018836779098880207 1
# 174 0.0013196951544457468 1
# 175 0.001017655332697425 1
# 176 0.0008399252736241605 1
# 177 0.0007466243749325328 1
# 178 0.0007030100871256198 1
# 179 0.0006801315844049301 1
# 180 0.0006690163342972831 1
# 181 0.0006613186702256902 1
# 182 0.0006554829560217063 1
# 183 0.0006498584491827997 1
# 184 0.0006440723114116363 1
# 185 0.0006369137804737708 1
# 186 0.0006271844892247934 1
# 187 0.0006125880310752068 1
# 188 0.000590430129168981 1
# 189 0.0005564277840724741 1
# 190 0.0005132418900771559 1
# 191 0.0004660700085029738 1
# 192 0.0004278316561413865 1
# 193 0.0004000223725534584 1
# 194 0.00038032521361762493 1
# 195 0.00036485882257590666 1
# 196 0.00034945200928897875 1
# 197 0.0003318721586537675 1
# 198 0.00031114193337704397 1
# 199 0.0002879247351647006 1
# 200 0.0002641567501424377 1
# 201 0.0002422720073814754 1
# 202 0.0002242518100255158 1
# 203 0.00021016129577649005 1
# 204 0.00019705377737963862 1
# 205 0.00018384273566909339 1
# 206 0.0001702236697327663 1
# 207 0.00015681914714573333 1
# 208 0.0001460004847118298 1
# 209 0.00013868065418193507 1
# 210 0.00013419215696466275 1
# 211 0.0001313602558994567 1
# 212 0.0001286941699112402 1
# 213 0.0001255376851250457 1
# 214 0.00012178000053077451 1
# 215 0.00011841797565489859 1
# 216 0.0001154768231254719 1
# 217 0.00011286912196811197 1
# 218 0.00011124611953246801 1
# 219 0.00011014217661329056 1
# 220 0.00010945984420794671 1
# 221 0.00010897272715282453 1
# 222 0.00010856646025349323 1
# 223 0.00010816285805544541 1
# 224 0.00010769209221970492 1
# 225 0.00010709713664265843 1
# 226 0.00010628536584761074 1
# 227 0.00010513248384813213 1
# 228 0.00010353572039959854 1
# 229 0.00010153937889068955 1
# 230 9.949180245748252e-05 1
# 231 9.769120526321997e-05 1
# 232 9.61842589497998e-05 1
# 233 9.501680977659684e-05 1
# 234 9.404601953008457e-05 1
# 235 9.33133777706509e-05 1
# 236 9.272278356625142e-05 1
# 237 9.211957461069403e-05 1
# 238 9.13428562434772e-05 1
# 239 9.02026650000514e-05 1
# 240 8.837262836946192e-05 1
# 241 8.530489955107064e-05 1
# 242 8.036294992573248e-05 1
# 243 7.23232270380345e-05 1
# 244 6.315785739573207e-05 1
# 245 5.572207755095351e-05 1
# 246 5.0801336411561176e-05 1
# 247 4.8161908063661023e-05 1
# 248 4.655820656138713e-05 1
# 249 4.545250399196645e-05 1
# 250 4.464221247634245e-05 1
# 251 4.418662649836097e-05 1
# 252 4.380360356987815e-05 1
# 253 4.346371594307507e-05 1
# 254 4.310297635137061e-05 1
# 255 4.266545243698165e-05 1
# 256 4.2420108638606687e-05 1
# 257 4.22596432783621e-05 1
# 258 4.211795151424409e-05 1
# 259 4.196286658034625e-05 1
# 260 4.176637755514168e-05 1
# 261 4.148905731312841e-05 1
# 262 4.107377069693899e-05 1
# 263 4.0480842146727034e-05 1
# 264 3.9748240328422784e-05 1
# 265 3.9007119543516634e-05 1
# 266 3.836418874980336e-05 1
# 267 3.7865038257175616e-05 1
# 268 3.750092650619643e-05 1
# 269 3.721848223842788e-05 1
# 270 3.696272126351636e-05 1
# 271 3.667979995225283e-05 1
# 272 3.635429710583301e-05 1
# 273 3.597212658630372e-05 1
# 274 3.553115486084357e-05 1
# 275 3.5043797102629415e-05 1
# 276 3.4536257205431876e-05 1
# 277 3.4052590563433014e-05 1
# 278 3.35833544068956e-05 1
# 279 3.306221147616401e-05 1
# 280 3.240329029836281e-05 1
# 281 3.1616887525379534e-05 1
# 282 3.079321287015997e-05 1
# 283 3.0089443397105073e-05 1
# 284 2.9551618764559114e-05 1
# 285 2.900840168735935e-05 1
# 286 2.8386558769054107e-05 1
# 287 2.7662378487243893e-05 1
# 288 2.680872382456173e-05 1
# 289 2.5895993774490232e-05 1
# 290 2.5087703340281553e-05 1
# 291 2.4621800577949278e-05 1
# 292 2.4338996889975218e-05 1
# 293 2.409897614022604e-05 1
# 294 2.3831641643355743e-05 1
# 295 2.3698302145946035e-05 1
# 296 2.3605592422930945e-05 1
# 297 2.3505543481093086e-05 1
# 298 2.33736922141661e-05 1
# 299 2.3179417117662787e-05 1
# 300 2.288795715415423e-05 1
# 301 2.2485807310789002e-05 1
# 302 2.2021083212437735e-05 1
# 303 2.157671986386503e-05 1
# 304 2.121509678805489e-05 1
# 305 2.0953339381438795e-05 1
# 306 2.0755482800626484e-05 1
# 307 2.06000815841555e-05 1
# 308 2.0461477838784304e-05 1
# 309 2.0321007644915182e-05 1
# 310 2.0164845811188187e-05 1
# 311 1.9974068374045225e-05 1
# 312 1.9734015926125806e-05 1
# 313 1.943309008545231e-05 1
# 314 1.907446376859595e-05 1
# 315 1.8644777799596123e-05 1
# 316 1.8144218068062564e-05 1
# 317 1.761303073671753e-05 1
# 318 1.70176663643586e-05 1
# 319 1.6439114004943747e-05 1
# 320 1.5936798256564617e-05 1
# 321 1.5502288551931974e-05 1
# 322 1.5110018702706287e-05 1
# 323 1.4741386213643208e-05 1
# 324 1.4396120309659183e-05 1
# 325 1.411715482046888e-05 1
# 326 1.3928238025198365e-05 1
# 327 1.3796543860638035e-05 1
# 328 1.3662339600454131e-05 1
# 329 1.3459527521098194e-05 1
# 330 1.3373485531974823e-05 1
# 331 1.3325791445516156e-05 1
# 332 1.3277190018587614e-05 1
# 333 1.321614042642004e-05 1
# 334 1.313011447892216e-05 1
# 335 1.30004797658262e-05 1
# 336 1.2807593084675441e-05 1
# 337 1.2546668692456436e-05 1
# 338 1.2253154732681555e-05 1
# 339 1.1971283652397278e-05 1
# 340 1.1736734742154366e-05 1
# 341 1.156867493497797e-05 1
# 342 1.1450792869803938e-05 1
# 343 1.1364161730845735e-05 1
# 344 1.1291467523880625e-05 1
# 345 1.1220245064669218e-05 1
# 346 1.1139471738871898e-05 1
# 347 1.1034287722482216e-05 1
# 348 1.0887498441475112e-05 1
# 349 1.0669226095414703e-05 1
# 350 1.0360959729004624e-05 1
# 351 9.929221092182166e-06 1
# 352 9.379157352844236e-06 1
# 353 8.83240630678876e-06 1
# 354 8.422331814697777e-06 1
# 355 8.16464167838099e-06 1
# 356 7.984420373574375e-06 1
# 357 7.805859552340892e-06 1
# 358 7.63600220698059e-06 1
# 359 7.520119070473124e-06 1
# 360 7.437243523693657e-06 1
# 361 7.382049375969734e-06 1
# 362 7.344120375194736e-06 1
# 363 7.309191570562816e-06 1
# 364 7.254371889456897e-06 1
# 365 7.175183085288613e-06 1
# 366 7.137679891634191e-06 1
# 367 7.101994723629959e-06 1
# 368 7.054290947027556e-06 1
# 369 6.984847139597328e-06 1
# 370 6.884042282712877e-06 1
# 371 6.749893870987209e-06 1
# 372 6.6003673356621444e-06 1
# 373 6.457359477434229e-06 1
# 374 6.338457454616845e-06 1
# 375 6.2519803099868206e-06 1
# 376 6.190314607047042e-06 1
# 377 6.144124483812739e-06 1
# 378 6.1050593796041695e-06 1
# 379 6.066362671450543e-06 1
# 380 6.0226827742448335e-06 1
# 381 5.96687130865344e-06 1
# 382 5.8913088371383565e-06 1
# 383 5.785956216138614e-06 1
# 384 5.64231956210253e-06 1
# 385 5.449428923016058e-06 1
# 386 5.189923600508791e-06 1
# 387 4.896408986027569e-06 1
# 388 4.598176905024845e-06 1
# 389 4.339273027690034e-06 1
# 390 4.115750602935057e-06 1
# 391 3.954881840361606e-06 1
# 392 3.827844740869296e-06 1
# 393 3.7079129837182584e-06 1
# 394 3.5727372447156388e-06 1
# 395 3.4589133095829983e-06 1
# 396 3.3127358788097033e-06 1
# 397 3.154986968836968e-06 1
# 398 2.6559156306082827e-06 1
# 399 2.237975278046235e-06 1
# 400 2.122606503267887e-06 1
# 401 2.0374284727798693e-06 1
# 402 2.00038335393685e-06 1
# 403 1.969993430257978e-06 1
# 404 1.9442302640649315e-06 1
# 405 1.913235876144462e-06 1
# 406 1.876243356994621e-06 1
# 407 1.8349985794700601e-06 1
# 408 1.795497527689482e-06 1
# 409 1.7618989931070816e-06 1
# 410 1.735975099974803e-06 1
# 411 1.7161475704353958e-06 1
# 412 1.6982017566197214e-06 1
# 413 1.6787494050504263e-06 1
# 414 1.6529969686095098e-06 1
# 415 1.616686730382136e-06 1
# 416 1.563978889529369e-06 1
# 417 1.49230493050401e-06 1
# 418 1.403392746190909e-06 1
# 419 1.3008606516296906e-06 1
# 420 1.187889532339135e-06 1
# 421 1.045026876474493e-06 1
# 422 8.73294984675356e-07 1
# 423 6.495849552264727e-07 1
# 424 4.10618156436549e-07 1
# 425 2.511520263044155e-07 1
# 426 1.7683122198191051e-07 1
# 427 1.1536641098777024e-07 1
# 428 7.94221062931605e-08 1
# 429 6.791195112000312e-08 1
# 430 6.127132865193998e-08 1
# 431 5.8607109544285884e-08 1
# 432 5.658448753252977e-08 1
# 433 5.5421692157282616e-08 1
# 434 5.4462000821272506e-08 1
# 435 5.355175607085722e-08 1
# 436 5.250210134573504e-08 1
# 437 5.113509648819379e-08 1
# 438 4.916184301856583e-08 1
# 439 4.6257556221633913e-08 1
# 440 4.2046582375381456e-08 1
# 441 3.702191354749129e-08 1
# 442 3.2131209562151477e-08 1
# 443 2.82119363753822e-08 1
# 444 2.5491931326653815e-08 1
# 445 2.373316756926522e-08 1
# 446 2.2658890379535882e-08 1
# 447 2.1806383491997883e-08 1
# 448 2.097976726954192e-08 1
# 449 2.0050929031121704e-08 1
# 450 1.8895275737910655e-08 1
# 451 1.7482338415592172e-08 1
# 452 1.578700600206217e-08 1
# 453 1.4054543863957449e-08 1
# 454 1.2416209368251758e-08 1
# 455 1.1073023080998321e-08 1
# 456 9.870147066686056e-09 1
# 457 8.735016999491165e-09 1
# 458 7.811378916083966e-09 1
# 459 7.089730751607286e-09 1
# 460 6.6012682042497936e-09 1
# 461 6.270155143111956e-09 1
# 462 6.025355417631799e-09 1
# 463 5.823755539863591e-09 1
# 464 5.656693539806042e-09 1
# 465 5.520885956278535e-09 1
# 466 5.4143713112907546e-09 1
# 467 5.336002568550832e-09 1
# 468 5.269198739220222e-09 1
# 469 5.143443288753057e-09 1
# 470 5.066261310325798e-09 1
# 471 5.031906240591642e-09 1
# 472 4.99874189130802e-09 1
# 473 4.958886816836727e-09 1
# 474 4.902151965731136e-09 1
# 475 4.8173018155569145e-09 1
# 476 4.693592554260193e-09 1
# 477 4.539731732520155e-09 1
# 478 4.3857255276747995e-09 1
# 479 4.2580305397347504e-09 1
# 480 4.156328775631477e-09 1
# 481 4.0687895638387604e-09 1
# 482 3.989732111934693e-09 1
# 483 3.92479851947222e-09 1
# 484 3.8788822714213955e-09 1
# 485 3.8380291091142966e-09 1
# 486 3.792379851617361e-09 1
# 487 3.732012105203459e-09 1
# 488 3.636608894003801e-09 1
# 489 3.4862742320122097e-09 1
# 490 3.2243763610330674e-09 1
# 491 2.874618260521913e-09 1
# 492 2.5575500613484566e-09 1
# 493 2.370329386493544e-09 1
# 494 2.2872104886211713e-09 1
# 495 2.2406819128596827e-09 1
# 496 2.208695978721926e-09 1
# 497 2.1836799614363465e-09 1
# 498 2.160227371744176e-09 1
# 499 2.133776504460615e-09 1
# 500 2.1056799400459923e-09 1
# 501 2.0666853084283904e-09 1
# 502 2.022243363812311e-09 1
# 503 1.9375150483965466e-09 1
# 504 1.844424394504777e-09 1
# 505 1.563289751496418e-09 1
# 506 1.3212394154520464e-09 1
# 507 1.2933945816577024e-09 1
# 508 1.2716169680502815e-09 1
# 509 1.243065579898239e-09 1
# 510 1.2135667756137397e-09 1
# 511 1.1742813025211923e-09 1
# 512 1.1355205352113554e-09 1
# 513 1.13135553364748e-09 0
# GMRES converged in 514 iterations
# ---Bi-cgstab---
# Converged
# Bi-cgstab error 6.191080631928035e-10

# %%
x0 = np.zeros(2*Ntot,dtype=complex)
for i in range(2*Ntot):  
    theta = np.random.uniform(0,2*pi)
    x0[i] = np.cos(theta) + 1j*np.sin(theta)
nu1, nu2 = 0, 2
Nit = 3
amg = AMG(D,nu1,nu2)
amg.tv(Nit)
P, PH = amg.get_p()
max_iter = 100
tol = 1e-10
x_sol = amg.TwoGrid(max_iter,tol,x0,phi,True)
# Out:
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# Bi-cgstab converged for Dc
# iteration 0 error 0.4133956047252367
# Bi-cgstab converged for Dc
# iteration 1 error 0.010746078232563454
# Bi-cgstab converged for Dc
# iteration 2 error 0.00021769322921445097
# Bi-cgstab converged for Dc
# iteration 3 error 8.802770663949672e-06
# Bi-cgstab converged for Dc
# iteration 4 error 1.856436896201691e-07
# Bi-cgstab converged for Dc
# iteration 5 error 4.370563167974008e-09
# Bi-cgstab converged for Dc
# iteration 6 error 1.1086753940101427e-09
# two-grid converged in 7 iterations. Error  1.1086753940101427e-09
# C:\Users\jafan\anaconda3\Lib\site-packages\scipy\sparse\_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %%
for i in range(2*Ntot):
    line_new = '{:>12}  {:>12}'.format(x_sol[i], x_gmres[i])
    print(line_new)
# Out:
# (-2.1726249052054336+2.1802889463334734j)  (-2.1726249055465083+2.1802889465163147j)
# (1.208795568563387+1.5457706873720471j)  (1.2087955684324825+1.5457706877394737j)
# (-4.813209192441747-2.2441434290525115j)  (-4.813209193316939-2.24414342939905j)
# (-0.5802144654553681+3.1143858996485485j)  (-0.5802144658207903+3.1143858996851996j)
# (1.7135761073650704+1.4182942189339929j)  (1.7135761077915654+1.418294219474975j)
# (0.06846565813443416-3.4215391427640647j)  (0.06846565834462937-3.421539143189889j)
# (-1.2644788056150855+1.1841018864537018j)  (-1.2644788061866805+1.184101886772839j)
# (1.8163703446458217-0.4407392577409726j)  (1.816370344523054-0.4407392578339342j)
# (-0.28838562326478284-0.9913864426180462j)  (-0.2883856234317748-0.9913864431385768j)
# (0.254697481394958-0.35986914128049746j)  (0.25469748162958294-0.35986914136134784j)
# (0.24022115482063347+0.43737908934662856j)  (0.24022115518645865+0.4373790890125523j)
# (-0.7241292078074019+0.21031081732642115j)  (-0.7241292076826945+0.21031081730529205j)
# (-1.8673575696495577-0.18574250283795382j)  (-1.8673575697602973-0.1857425021401662j)
# (0.605771945052691-0.6391260988452109j)  (0.6057719450375811-0.6391260987287172j)
# (0.786477370497351+0.9852553896699474j)  (0.7864773705960315+0.9852553902295431j)
# (0.5690965023277786-1.547108743137714j)  (0.5690965024886576-1.5471087428911636j)
# (-0.7226247434426726-0.011925363869008677j)  (-0.7226247431963044-0.011925363996157812j)
# (-0.7126928460192096-1.6302037654020036j)  (-0.712692845819675-1.630203765608222j)
# (-2.534093536099655-1.0659560003184427j)  (-2.534093536365553-1.0659560003057436j)
# (1.5511545431948615+1.4063028663531794j)  (1.551154543027763+1.4063028664771633j)
# (0.9366469087721244-0.23368846354500622j)  (0.9366469090830684-0.23368846371088345j)
# (-1.5935254191898445+1.1282423424757337j)  (-1.5935254193210362+1.128242342425397j)
# (-0.15651357916336892+0.12468492120161155j)  (-0.1565135793808334+0.12468492150038447j)
# (0.11891377965295799-1.7193108302046425j)  (0.11891377963879457-1.7193108301605167j)
# (1.0802234588722255+1.128839622632124j)  (1.080223459207663+1.1288396225033013j)
# (-1.3701409308346262+0.5718034181348907j)  (-1.3701409311322224+0.5718034183532767j)
# (0.8372943488734891+0.4444501119551913j)  (0.8372943489517413+0.444450111968063j)
# (0.5486540289413583+1.4505480667382322j)  (0.5486540293829648+1.4505480667983106j)
# (0.1324977030273299-1.7343543284033665j)  (0.13249770277828374-1.734354328261235j)
# (0.8652831730236704+0.33221690083568395j)  (0.8652831731170324+0.33221690096215695j)
# (-0.2985212665297633+0.5034355776591157j)  (-0.2985212663466705+0.5034355778971907j)
# (0.14358521488050824-1.7836333473870198j)  (0.14358521507650804-1.7836333473572679j)
# (-1.0887179180427204+0.7320755017829987j)  (-1.088717917886282+0.7320755013956293j)
# (-0.6477078280591576+0.9813965253692437j)  (-0.6477078281046599+0.9813965251396924j)
# (-0.7029850843713985-1.6036000241558814j)  (-0.7029850842272168-1.6036000245554858j)
# (-0.3471880141066648+1.4622954154793801j)  (-0.34718801410660177+1.4622954153116747j)
# (-1.7020238304996007-0.30402849908759844j)  (-1.7020238309050144-0.30402849911912866j)
# (1.5813356474343156-0.5802665214390962j)  (1.581335647330724-0.5802665215803927j)
# (0.9624555972660899-0.9951109778597208j)  (0.9624555975267414-0.995110977845059j)
# (-1.3585911703960531+0.692809509459518j)  (-1.35859117055636+0.692809509588926j)
# (-0.2432928496466433+0.6474439919736417j)  (-0.24329284960066366+0.6474439920569437j)
# (-0.18664661418125822-1.5291109952260509j)  (-0.18664661434853314-1.5291109955639524j)
# (0.42477128539767794+0.2566335331107867j)  (0.42477128567572153+0.2566335332579417j)
# (0.35192522608500754+0.0477762435386477j)  (0.3519252264211936+0.04777624332982521j)
# (0.7656618170873529+0.6882971960263922j)  (0.7656618173770785+0.6882971954689948j)
# (-0.004408496848684718+0.00524094130019942j)  (-0.004408496936067939+0.005240941043918002j)
# (0.36061636645235784+0.15908569600781708j)  (0.3606163666575933+0.1590856965473905j)
# (-0.06329363743373459-2.15009413157493j)  (-0.06329363732757706-2.1500941316311j)
# (-0.04675870420541109-0.3666647904133568j)  (-0.04675870449921414-0.366664790956751j)
# (0.5700758038857254+0.7627153213108936j)  (0.5700758037502842+0.7627153210561591j)
# (-0.9271564443441089+1.318453813280914j)  (-0.9271564446011265+1.3184538138238657j)
# (-1.2626661391009917-1.192662167755661j)  (-1.262666139386411-1.192662167537496j)
# (1.1092178834791573+2.3710684043041397j)  (1.109217883786358+2.371068404625987j)
# (-0.855486487620136-0.5407670212349086j)  (-0.855486487497337-0.5407670209963693j)
# (1.2379111673882985-2.0280990692321903j)  (1.2379111675456707-2.0280990694629804j)
# (-0.5154757609724937+0.20759474644684317j)  (-0.5154757613160275+0.20759474644135856j)
# (0.23564594615845366-0.5571178616711593j)  (0.23564594620930956-0.5571178618745948j)
# (0.2206002684179633-0.12083079458330284j)  (0.22060026814246864-0.12083079428485309j)
# (-0.8008195506299638+0.017345938159613966j)  (-0.8008195509790577+0.017345938102716722j)
# (0.30217646513210306-1.00461519113513j)  (0.3021764652760039-1.0046151908245609j)
# (-0.6313667517955726+1.301861622333372j)  (-0.6313667515847012+1.3018616231899414j)
# (-0.5787820693491047+0.3526723929928996j)  (-0.5787820690971878+0.35267239304189024j)
# (-1.3811383503806436+0.4257771579073414j)  (-1.3811383509718453+0.42577715864649635j)
# (1.2916536041263948-0.22694245201515723j)  (1.2916536042575957-0.22694245199037158j)
# (-0.5323900442901601+0.4991325647900056j)  (-0.5323900449933882+0.4991325653871038j)
# (0.39610537894015546+1.06801080468911j)  (0.3961053784969339+1.0680108045335677j)
# (0.19425492791036045+0.7167159292491982j)  (0.19425492857427346+0.7167159293909311j)
# (1.5614455895402792+1.1354133844044827j)  (1.561445589683972+1.1354133849116488j)
# (-0.2806383324496762-2.2371194414177693j)  (-0.28063833294443735-2.2371194414649644j)
# (-0.5873066161566347+1.2271048040874992j)  (-0.587306616320407+1.2271048040403152j)
# (-0.11892727564254732-1.234566547690324j)  (-0.11892727586856325-1.2345665476498553j)
# (-0.6299030985039493+0.056197950504559314j)  (-0.6299030986028044+0.05619795034679576j)
# (0.008357710864200509+0.21917018182773498j)  (0.008357710809786586+0.2191701821712589j)
# (-1.3701951452734449-0.8394392983635277j)  (-1.3701951453371162-0.8394392986072478j)
# (0.48301246881217585+1.6819422400399688j)  (0.48301246945798737+1.6819422403587923j)
# (-1.5763765615436445+1.4921771776426218j)  (-1.576376561638083+1.492177177869934j)
# (-0.8977507832609898-2.7008813802849447j)  (-0.8977507848132371-2.7008813805939407j)
# (0.9106840918347151-1.150493898581259j)  (0.9106840916899215-1.150493898921974j)
# (-2.113066863539919+0.31635671130824j)  (-2.1130668641147157+0.3163567126583403j)
# (0.921843155405933-0.4133592565071405j)  (0.9218431551477402-0.41335925709690874j)
# (0.4719060917827371-1.6467898923206776j)  (0.47190609194188965-1.6467898926299294j)
# (0.9311134498911333-2.645661932905532j)  (0.9311134501416917-2.6456619331783497j)
# (-0.13128691915225246+2.008992284769238j)  (-0.1312869187629726+2.00899228518533j)
# (-2.004155333341675+1.8678776963780972j)  (-2.0041553341878413+1.8678776965483452j)
# (-1.5612685457181759-1.4942563053332625j)  (-1.5612685460570281-1.4942563053840614j)
# (1.6293865981129383-1.203198506544104j)  (1.629386598207237-1.2031985069063516j)
# (0.8338438563763411-2.0625349465342855j)  (0.8338438562551453-2.0625349469915686j)
# (-0.10523469142189487-0.41553878432607905j)  (-0.10523469112182433-0.41553878437688196j)
# (-2.072042319875604-0.9737515080446086j)  (-2.072042320590167-0.9737515077209782j)
# (-0.07786895808909179-0.6243378909159976j)  (-0.07786895810971817-0.6243378912003928j)
# (-1.0803069874333093+2.423981412968117j)  (-1.0803069868502073+2.4239814141884057j)
# (-0.6939733204476606+1.2395198304644717j)  (-0.6939733204926262+1.2395198305811699j)
# (-4.079298415573216+1.3151861406086733j)  (-4.079298415963323+1.3151861425995583j)
# (-0.6800225983483944+0.4836962489963836j)  (-0.6800225982487683+0.48369624926848576j)
# (0.441842923384381-2.720597866816389j)  (0.4418429225267794-2.720597867989865j)
# (-0.16902347589280017-0.24505850840416266j)  (-0.1690234762033345-0.24505850796846593j)
# (-1.1848155192932388+2.1964931645895107j)  (-1.1848155194867893+2.1964931645935892j)
# (-3.7765306659146134-0.19626471573187426j)  (-3.776530666884084-0.19626471541241222j)
# (1.706779554531239+1.4609839573633978j)  (1.7067795548778522+1.4609839572995824j)
# (-1.4885765873570505+0.921573377326229j)  (-1.4885765875640602+0.9215733780644385j)
# (1.1055780315321757+1.6973995382522664j)  (1.105578031891044+1.6973995386647558j)
# (-2.1423897001506735-1.8386661426328925j)  (-2.1423897005378754-1.8386661424224064j)
# (-0.419380529777381+0.04209833763116028j)  (-0.4193805301192101+0.04209833789892384j)
# (0.7579408826574209+0.26262985694033447j)  (0.7579408823889131+0.2626298567748742j)
# (0.9369290629422157+0.0032138211869387583j)  (0.9369290637253563+0.003213820741985872j)
# (-0.014701860866231813-0.2879504789920863j)  (-0.01470186076520883-0.28795047893615533j)
# (1.408887141304106+1.3705156628794726j)  (1.4088871424595353+1.3705156624803598j)
# (-0.0284815078890824-0.3024774871349532j)  (-0.02848150760097965-0.30247748738321933j)
# (-1.1452829510493405+2.224118739417407j)  (-1.1452829501142154+2.224118739988945j)
# (0.02726756615305862-0.13755017510734152j)  (0.027267566730133426-0.13755017523676102j)
# (0.023087389276924206+0.3552660371631464j)  (0.02308738915365155+0.3552660375032314j)
# (1.2307961854859368+0.9437479244118561j)  (1.2307961865360044+0.9437479243541553j)
# (1.1318498795175098-1.6872973144493197j)  (1.1318498793313283-1.6872973142823675j)
# (1.6395076860049234-2.0679617392423033j)  (1.6395076860766684-2.06796173981791j)
# (2.123182515991297+0.08855727744264089j)  (2.1231825166242126+0.088557277347496j)
# (-0.9351077025326439+1.1406982007278585j)  (-0.9351077023748724+1.140698201375792j)
# (1.3889886407207153+1.0864268826787014j)  (1.3889886412126924+1.0864268827839239j)
# (-4.396161550971741-0.045944191794413246j)  (-4.396161551620996-0.04594419164811341j)
# (-1.4453887808248953+1.2723495382511074j)  (-1.4453887811727557+1.2723495387840442j)
# (-0.09149262284677132-1.2303092556146031j)  (-0.09149262283268787-1.230309255649758j)
# (0.7662247509530553-0.05567329445667993j)  (0.7662247516983829-0.05567329481326462j)
# (-0.2224720840470705+0.5632462560669118j)  (-0.22247208405937963+0.5632462561060732j)
# (0.7388432210238296-0.25712073946243286j)  (0.7388432207519285-0.25712074042253635j)
# (0.5225340729991296+0.8124121252369989j)  (0.5225340728798414+0.8124121251814512j)
# (-0.45123508736193874-1.0037836795804964j)  (-0.4512350882843621-1.003783678953253j)
# (0.7459372691389794+0.2659971185947446j)  (0.7459372691535516+0.2659971189478873j)
# (1.242865310568492-0.1285292171420506j)  (1.24286531070645-0.12852921650556356j)
# (1.2882905189499165-1.5632760615956818j)  (1.2882905193324314-1.5632760615464691j)

# %% [markdown]
# ### Some tests for a two-grid method using GRMES as smoother

# %%
dim = Nx*Nt*2
D = np.zeros((dim,dim),dtype=complex)
phi = np.zeros(dim,dtype=complex)
x0 = np.zeros(2*Ntot,dtype=complex)
iterations = []
for conf in range(50):
    row, col, re, im = DatosMat("build/D{0}.dat".format(conf))
    for i in range(dim*dim):
        D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
    row, col, re, im = DatosMat("build/phi{0}.dat".format(conf))
    for i in range(dim):
        phi[i] = re[i] + 1j*im[i] 
    for i in range(2*Ntot):  
        theta = np.random.uniform(0,2*pi)
        x0[i] = np.cos(theta) + 1j*np.sin(theta)
    nu1, nu2 = 0, 2
    Nit = 3
    print("Conf #{0}".format(conf))
    amg = AMG(D,nu1,nu2)
    amg.tv(Nit)
    P, PH = amg.get_p()
    max_iter = 100
    tol = 1e-10
    x_sol = amg.TwoGrid(max_iter,tol,x0,phi,False)
    iterations.append(amg.get_iterations())
iterations = np.array(iterations)
print("Number of iterations: {0} +- {1}".format(np.round(np.mean(iterations),4), np.round(np.std(iterations)/np.sqrt(50),4  ) ))
# Out:
# Conf #0
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  9.489338785611467e-10
# C:\Users\jafan\anaconda3\Lib\site-packages\scipy\sparse\_index.py:143: SparseEfficiencyWarning: Changing the sparsity structure of a csc_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Conf #1
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  1.112435510796934e-09
# Conf #2
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 9 iterations. Error  1.0703930183988648e-09
# Conf #3
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 12 iterations. Error  1.0689696594752356e-09
# Conf #4
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 14 iterations. Error  1.1087117495976607e-09
# Conf #5
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 19 iterations. Error  1.1278068785280695e-09
# Conf #6
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 10 iterations. Error  1.113558309660425e-09
# Conf #7
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 13 iterations. Error  1.0715411844413599e-09
# Conf #8
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 14 iterations. Error  1.0751563361895516e-09
# Conf #9
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 11 iterations. Error  1.0599004008292638e-09
# Conf #10
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 13 iterations. Error  1.1300383336497814e-09
# Conf #11
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 10 iterations. Error  1.0735558495178038e-09
# Conf #12
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0897241583387483e-09
# Conf #13
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  1.0943759721430772e-09
# Conf #14
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1013793668274212e-09
# Conf #15
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1016653710926047e-09
# Conf #16
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0860397017357291e-09
# Conf #17
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 10 iterations. Error  1.0771171496182779e-09
# Conf #18
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  1.0365085977366255e-09
# Conf #19
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  1.0532752460659826e-09
# Conf #20
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  1.1174453975480548e-09
# Conf #21
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1107828212567987e-09
# Conf #22
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  9.982019152897846e-10
# Conf #23
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0330490443892438e-09
# Conf #24
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0648645373200789e-09
# Conf #25
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0294328804370283e-09
# Conf #26
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1044874304132356e-09
# Conf #27
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  9.993517852656334e-10
# Conf #28
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  1.1162275587636558e-09
# Conf #29
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 10 iterations. Error  1.1023703742826656e-09
# Conf #30
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 9 iterations. Error  1.123145946464727e-09
# Conf #31
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  1.0872944655467581e-09
# Conf #32
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 22 iterations. Error  1.09226585374197e-09
# Conf #33
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# Conf #34
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1220519135210966e-09
# Conf #35
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 10 iterations. Error  1.076685833344627e-09
# Conf #36
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  9.930190584036344e-10
# Conf #37
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  9.282319688532275e-10
# Conf #38
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 8 iterations. Error  1.0435060556532904e-09
# Conf #39
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.095562395983787e-09
# Conf #40
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  1.0897499021611602e-09
# Conf #41
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1182708652556668e-09
# Conf #42
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.1064737221006734e-09
# Conf #43
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0742925651611645e-09
# Conf #44
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0675933954717359e-09
# Conf #45
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0933321393702126e-09
# Conf #46
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0228374267198282e-09
# Conf #47
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  9.617535745380076e-10
# Conf #48
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 7 iterations. Error  1.0049791640592153e-09
# Conf #49
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# two-grid converged in 6 iterations. Error  1.1033978504408753e-09
# Number of iterations: 10.48 +- 1.8642

# %% [markdown]
# ### Tests using GMRES

# %%
dim = Nx*Nt*2
D = np.zeros((dim,dim),dtype=complex)
phi = np.zeros(dim,dtype=complex)
x0 = np.zeros(2*Ntot,dtype=complex)
tol = 1e-10
iterations = []
for conf in range(50):
    row, col, re, im = DatosMat("build/D{0}.dat".format(conf))
    for i in range(dim*dim):
        D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
    row, col, re, im = DatosMat("build/phi{0}.dat".format(conf))
    for i in range(dim):
        phi[i] = re[i] + 1j*im[i] 
    for i in range(2*Ntot):  
        theta = np.random.uniform(0,2*pi)
        x0[i] = np.cos(theta) + 1j*np.sin(theta)
    Dsparse = csc_array(D)
    x_gmres = x0
    #GMRES
    print("Conf #{0}".format(conf))
    max_err = tol*np.linalg.norm(phi)
    err = 1
    k = 0
    while k<1000 and err>max_err:
        x_gmres, exit_code = gmres(Dsparse, phi, x0=x_gmres, tol=1e-10, atol=0.0, maxiter=1)
        r = phi - Dsparse.dot(x_gmres)
        err = np.sqrt(np.real(np.vdot(r,r)))
        if err<=max_err:
            print("GMRES converged in {0} iterations".format(k+1))
            iterations.append([k+1])
        k += 1
iterations = np.array(iterations)
print("Number of iterations: {0} +- {1}".format(np.round(np.mean(iterations),4), np.round(np.std(iterations)/np.sqrt(50),4  ) ))
# Out:
# Conf #0
# GMRES converged in 522 iterations
# Conf #1
# Conf #2
# Conf #3
# Conf #4
# Conf #5
# Conf #6
# Conf #7
# Conf #8
# Conf #9
# Conf #10
# Conf #11
# Conf #12
# GMRES converged in 82 iterations
# Conf #13
# GMRES converged in 92 iterations
# Conf #14
# GMRES converged in 83 iterations
# Conf #15
# GMRES converged in 79 iterations
# Conf #16
# GMRES converged in 76 iterations
# Conf #17
# Conf #18
# GMRES converged in 56 iterations
# Conf #19
# GMRES converged in 111 iterations
# Conf #20
# GMRES converged in 176 iterations
# Conf #21
# GMRES converged in 223 iterations
# Conf #22
# GMRES converged in 204 iterations
# Conf #23
# GMRES converged in 361 iterations
# Conf #24
# GMRES converged in 535 iterations
# Conf #25
# GMRES converged in 570 iterations
# Conf #26
# GMRES converged in 554 iterations
# Conf #27
# Conf #28
# Conf #29
# Conf #30
# Conf #31
# GMRES converged in 64 iterations
# Conf #32
# Conf #33
# Conf #34
# GMRES converged in 660 iterations
# Conf #35
# GMRES converged in 445 iterations
# Conf #36
# GMRES converged in 419 iterations
# Conf #37
# GMRES converged in 484 iterations
# Conf #38
# GMRES converged in 543 iterations
# Conf #39
# GMRES converged in 516 iterations
# Conf #40
# GMRES converged in 624 iterations
# Conf #41
# GMRES converged in 508 iterations
# Conf #42
# GMRES converged in 624 iterations
# Conf #43
# GMRES converged in 649 iterations
# Conf #44
# GMRES converged in 71 iterations
# Conf #45
# GMRES converged in 65 iterations
# Conf #46
# GMRES converged in 385 iterations
# Conf #47
# GMRES converged in 56 iterations
# Conf #48
# GMRES converged in 45 iterations
# Conf #49
# GMRES converged in 61 iterations
# Number of iterations: 310.7188 +- 31.9792
