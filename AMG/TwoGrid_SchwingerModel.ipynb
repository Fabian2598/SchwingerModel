# %%
from scipy.sparse import csc_array
from scipy.sparse.linalg import bicgstab
from scipy.sparse.linalg import cg
from scipy.sparse.linalg import gmres
import numpy as np
import matplotlib.pyplot as plt
pi = np.pi

from copy import deepcopy

# %%
def DatosMat(path):
    data = [[],[],[],[]]
    with open(path) as fobj:
        for i, line in enumerate(fobj):
           # data.append([])
            if line.rsplit() != []:
                row = line.rsplit()   
                for j in range(len(row)):
                    data[j].append(float(row[j]))     
    return data

def DatosVec(path):
    data = [[],[],[]]
    with open(path) as fobj:
        for i, line in enumerate(fobj):
           # data.append([])
            if line.rsplit() != []:
                row = line.rsplit()   
                for j in range(len(row)):
                    data[j].append(float(row[j]))     
    return data

def Kaczmarz(A,N,phi,x0,max_iter,tol):
    x = x0
    r = phi - A.dot(x)
    err = 1
    k = 0
    while k<max_iter and err>tol:
        for i in range(N):
            v = np.eye(1,N,i).reshape(N)
            Av = A @ v
            alpha = np.vdot(Av,r) / np.vdot(Av,Av)
            x += alpha * v
            r = phi - A.dot(x)
        err = np.sqrt(np.real(np.vdot(r,r)))
        if err<tol:
            print("Kaczmarz for D converged in {0} iterations. Error {1}".format(k+1,err))
            return x
        k += 1
    print("Kaczmarz for D did NOT converge in {0} iterations. Error {1}".format(max_iter,err))
    return x

# %%
Nx, Nt = 20, 20
block_x, block_t = 4, 4
x_elements, t_elements = int(Nx/block_x), int(Nt/block_t)
Ntest, Nagg = 15, 2*(block_x*block_t)
Ntot = Nx*Nt
Coords = np.zeros((Nx,Nt,2),dtype=int)
for x in range(Nx):
    for t in range(Nt):
        for s in range(2):
            Coords[x,t,s] = x * Nt * 2 + t * 2 + s
XCoord = np.zeros(2*Nx*Nt,dtype=int)
TCoord = np.zeros(2*Nx*Nt,dtype=int)
SCoord = np.zeros(2*Nx*Nt,dtype=int)
Agg = np.zeros((2*block_x*block_t,x_elements*t_elements),dtype=int)
print("Lattice dimensions Nx={0}, Nt={1}".format(Nx,Nt))
print("Number of aggregates {0}".format(Nagg))
print("Block_x={0}, Block_t={1}".format(block_x,block_t))
print("Number of test vectors {0}".format(Ntest))
print("Matrix dimension {0}".format(2*Ntot))
print("Coarse grid dimension {0}".format(Nagg*Ntest))
# Out:
# Lattice dimensions Nx=20, Nt=20
# Number of aggregates 32
# Block_x=4, Block_t=4
# Number of test vectors 15
# Matrix dimension 800
# Coarse grid dimension 480

# %%
#Computing the aggregates
for x in range(block_x):
    for t in range(block_t):
        for s in range(2):
            x0, t0 = x * x_elements, t * t_elements
            x1, t1 = (x+1) * x_elements, (t+1) * t_elements
            aggregate = x * block_t * 2 + t * 2 + s
            count = 0
            for X in range(x0,x1):
                for T in range(t0,t1):
                    i = X * Nt * 2 + T * 2 + s
                    XCoord[i] , TCoord[i], SCoord[i] = X, T, s
                    Agg[aggregate][count] = i
                    count += 1

# %%
class AMG():
    def __init__(self,D,nu1,nu2):
        self.test_vectors = np.zeros((Ntest,2*Ntot),dtype=complex) 
        self.P = np.zeros((2*Ntot,Ntest*Nagg),dtype=complex) 
        self.PH = np.zeros((Ntest*Nagg,2*Ntot),dtype=complex) 
        self.D = csc_array(D) #Dirac matrix
        self.Dc = np.zeros((Ntest*Nagg,Ntest*Nagg),dtype=complex) 
        self.nu1 = nu1
        self.nu2 = nu2
        self.it = 0 #Parameter to measure iterations for convergence

    def get_p(self):
        return self.P, self.PH
    def get_Dc(self):
        return self.Dc
    def get_iterations(self):
        return self.it

    def orthonormalize(self):
        v_chopped = [] #Columns of the interpolator
        for i in range(Ntest*Nagg):
            v = np.eye(1,Ntest*Nagg,i).reshape(Ntest*Nagg)
            v_chopped.append(self.P @ v)
        v_chopped = np.array(v_chopped)        
        for i in range(Nagg):
            for nt in range(Ntest):
                for j in range(nt):
                    #vdot(a,b) = a* . b /= b* . a = vdot(b,a)
                    proj = np.vdot(v_chopped[j * Nagg + i],v_chopped[nt * Nagg + i])
                    v_chopped[nt * Nagg + i] -= proj * v_chopped[j * Nagg + i]
                v_chopped[nt*Nagg+i] /= np.linalg.norm(v_chopped[nt*Nagg+i])
        matrix =  np.zeros((2*Ntot,Ntest*Nagg),dtype=complex) 
        for i in range(Ntest*Nagg):
            matrix[:,i] = v_chopped[i]
        self.P = matrix
        self.PH = csc_array(np.conjugate(np.transpose(self.P)))
        self.P = csc_array(self.P)
        self.Dc = (self.PH @(self.D @ self.P)) #matrix multiplication

    def tv(self,Nit):  
        test_vectors_copy = np.zeros((Ntest,2*Ntot),dtype=complex) 
        for i in range(Ntest): 
            for j in range(2*Ntot):
                theta = np.random.uniform(0,2*pi)
                self.test_vectors[i,j] = np.cos(theta) + 1j*np.sin(theta)
        for i in range(Ntest):
            self.test_vectors[i], exit_code = gmres(self.D, self.test_vectors[i], x0=self.test_vectors[i] ,maxiter=20)
            #self.test_vectors[i] = Kaczmarz(self.D,2*Ntot,self.test_vectors[i],self.test_vectors[i],20,1e-10)
        self.P_v() #Assemble P
        self.orthonormalize() #Orthonormalize
        print("Improving interpolator")
        for n in range(Nit):
            print("n={0} out of Nit={1}".format(n,Nit))
            for i in range(Ntest):
                self.test_vectors[i] = self.TwoGrid(1,1e-10,self.test_vectors[i],self.test_vectors[i],False)
            self.P_v() #Assemble P
            self.orthonormalize() #Orthonormalize
            
             
    def P_v(self):
        #Assembling the interpolator
        for can_vec in range(Ntest*Nagg):   
            P_v = np.zeros(2*Ntot,dtype=complex)
            v = np.eye(1,Ntest*Nagg,can_vec).reshape(Ntest*Nagg)
            for j in range(Ntest*Nagg):
                k = int(j / Nagg)
                a = int(j % Nagg)
                for i in range(len(Agg[a])):
                    x, t, s = XCoord[Agg[a,i]], TCoord[Agg[a,i]], SCoord[Agg[a,i]]
                    P_v[Coords[x,t,s]]  += self.test_vectors[k,Coords[x,t,s]] * v[j]
            self.P[:,can_vec] = P_v   
        self.PH = csc_array(np.conjugate(np.transpose(self.P)))
        self.P = csc_array(self.P)
        self.Dc = (self.PH @(self.D @ self.P)) #matrix multiplication
        
    def TwoGrid(self,max_iter,tol,x0,phi,message):
        #Solve D x = phi
        x = x0
        err = 1
        k = 0
        r0 = phi - self.D.dot(x)
        max_err = tol*np.linalg.norm(phi)
        while(k < max_iter and err > max_err):
            if self.nu1 > 0:
                x, exitCode = gmres(self.D, phi, x0=x , rtol=1e-10, atol=0.0, maxiter=nu1) 
                #x = Kaczmarz(self.D,2*Ntot,phi,x,nu1,1e-10)
            #Coarse grid correction
            Pt_r = self.PH.dot( (phi-self.D.dot(x)))
            Dc_inv, exit_code = bicgstab(self.Dc, Pt_r,x0=Pt_r,maxiter=10000, rtol=1e-10, atol=0.0) #Dc^-1 P^H(phi-Dx)
            if message==True:
                if exit_code == 0:
                    print("Bi-cgstab converged for Dc")
                else:
                    rc = Pt_r - self.Dc.dot(Dc_inv)
                    err_c = np.sqrt(np.real(np.vdot(rc,rc)))
                    print("Bi-cgstab did NOT converge for Dc. Error {0}".format(err_c))
            x += self.P.dot(Dc_inv)
            if self.nu2>0:
                x, exitCode = gmres(self.D, phi, x0=x ,rtol=1e-10, atol=0.0, maxiter=nu2)
                #x = Kaczmarz(self.D,2*Ntot,phi,x,nu2,1e-10)
            r = phi - self.D.dot(x)
            err = np.sqrt(np.real(np.vdot(r,r))) #complex dot product
            if message == True:
                print("iteration",k,"error",err)
            if err<=max_err:
                self.it = k+1
                print("two-grid converged in",k+1,"iterations. Error ",err)
                return x
            k+=1
        if message == True:
            print("two-grid did not converge in",max_iter,"iterations. Error ",err)
        self.it = max_iter
        return x

    def print_p(self):
        for i in range(2*Ntot):
            for j in range(Ntest*Nagg):
                print(self.P[i,j], end = " ")
            print('')

# %%
dim = Nx*Nt*2
print(dim)
D = np.zeros((dim,dim),dtype=complex)
row, col, re, im = DatosMat("build/D0.dat")
for i in range(dim*dim):
    D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
phi = np.zeros(dim,dtype=complex)
row, col, re, im = DatosMat("build/Phi0.dat")
for i in range(dim):
    phi[i] = re[i] + 1j*im[i]
# Out:
# 800

# %%
np.linalg.cond(D) #Condition number
# Out:
# np.float64(1381.5539301431472)

# %%
#Initial solution
x0 = np.zeros(2*Ntot,dtype=complex)
for i in range(2*Ntot):  
    theta = np.random.uniform(0,2*pi)
    x0[i] = np.cos(theta) + 1j*np.sin(theta)

# %%
Dsparse = csc_array(D)
x_gmres = x0
#GMRES
tol = 1e-10
print("---GMRES---")
for i in range(1000):
    x_gmres, exit_code = gmres(Dsparse, phi, x0=x_gmres, rtol=1e-10, atol=0.0, maxiter=1)
    r = phi - Dsparse.dot(x_gmres)
    err = np.sqrt(np.real(np.vdot(r,r)))
    print(i,err,exit_code)
    if err<=tol*np.linalg.norm(phi):
        print("GMRES converged in {0} iterations".format(i+1))
        break
#bi-cgstab
print("---Bi-cgstab---")
x_bi = x0
x_bi, exit_code = bicgstab(Dsparse, phi,x0=x_bi,maxiter=500, rtol=1e-10)
if exit_code == 0:
    print("Converged")
else:
    print("Did not converge")
r = phi - Dsparse.dot(x_bi)
err = np.sqrt(np.real(np.vdot(r,r)))
print("Bi-cgstab error {0}".format(err))
# Out:
# ---GMRES---
# 0 17.123544540437923 1
# 1 17.026376267531592 1
# 2 17.01688100937307 1
# ---Bi-cgstab---
# Did not converge
# Bi-cgstab error 58.31756475253755

# %%
x0 = np.zeros(2*Ntot,dtype=complex)
for i in range(2*Ntot):  
    theta = np.random.uniform(0,2*pi)
    x0[i] = np.cos(theta) + 1j*np.sin(theta)
nu1, nu2 = 0, 2
Nit = 3
amg = AMG(D,nu1,nu2)
amg.tv(Nit)
P, PH = amg.get_p()
max_iter = 100
tol = 1e-10
x_sol = amg.TwoGrid(max_iter,tol,x0,phi,True)
# Out:
# Improving interpolator
# n=0 out of Nit=3
# n=1 out of Nit=3
# n=2 out of Nit=3
# Bi-cgstab did NOT converge for Dc. Error 43.8624145925769
# iteration 0 error 47.39514650671097
# Bi-cgstab did NOT converge for Dc. Error 949.7924674242353
# iteration 1 error 973.7801918284185
# Bi-cgstab did NOT converge for Dc. Error 15022.189400799249
# iteration 2 error 11698.724135501083
# Bi-cgstab did NOT converge for Dc. Error 7738.796670812812
# iteration 3 error 8586.370880284336
# Bi-cgstab did NOT converge for Dc. Error 25818.779040125602
# iteration 4 error 23980.32885575272
# Bi-cgstab did NOT converge for Dc. Error 83564.51123368001
# iteration 5 error 60619.51737991654
# Bi-cgstab did NOT converge for Dc. Error 221640.28272066577
# iteration 6 error 214753.907172469
# Bi-cgstab did NOT converge for Dc. Error 544321.4288210954
# iteration 7 error 524548.5358915312
# Bi-cgstab did NOT converge for Dc. Error 1194396.2542814254
# iteration 8 error 1048094.7402659849
# Bi-cgstab did NOT converge for Dc. Error 3012649.860019099
# iteration 9 error 1711635.9334781093
# Bi-cgstab did NOT converge for Dc. Error 3790035.9132722956
# iteration 10 error 3340599.057170129
# Bi-cgstab did NOT converge for Dc. Error 8115336.781925223
# iteration 11 error 7900294.55898752
# Bi-cgstab did NOT converge for Dc. Error 16157241.142969059
# iteration 12 error 16954439.27494763
# Bi-cgstab did NOT converge for Dc. Error 37786449.77208224
# iteration 13 error 33801436.10837925
# Bi-cgstab did NOT converge for Dc. Error 86942337.22750315
# iteration 14 error 58047706.03365626
# Bi-cgstab did NOT converge for Dc. Error 66058394442.46375
# iteration 15 error 53546748971.40567
# Bi-cgstab did NOT converge for Dc. Error 129002394016.44528
# iteration 16 error 75826603105.13737
# Bi-cgstab did NOT converge for Dc. Error 132745368013.63802
# iteration 17 error 132496528797.38147
# Bi-cgstab did NOT converge for Dc. Error 356032189246.9396
# iteration 18 error 235842476468.87878
# Bi-cgstab did NOT converge for Dc. Error 1761803358275.8977
# iteration 19 error 1642678561744.0635
# Bi-cgstab did NOT converge for Dc. Error 2336124155146.9277
# iteration 20 error 2197630286671.8486
# Bi-cgstab did NOT converge for Dc. Error 5317701341294.778
# iteration 21 error 4497895761631.522
# Bi-cgstab did NOT converge for Dc. Error 15704304799864.076
# iteration 22 error 12207689348907.988
# Bi-cgstab did NOT converge for Dc. Error 13477103106061.68
# iteration 23 error 13834738156942.654
# Bi-cgstab did NOT converge for Dc. Error 32285749651071.574
# iteration 24 error 33202521073826.688
# Bi-cgstab did NOT converge for Dc. Error 78461487095771.38
# iteration 25 error 81188052577901.19
# Bi-cgstab did NOT converge for Dc. Error 820974042089969.2
# iteration 26 error 713199774344733.2
# Bi-cgstab did NOT converge for Dc. Error 2417786478194568.0
# iteration 27 error 2435210013404689.5
# Bi-cgstab did NOT converge for Dc. Error 5327717844932509.0
# iteration 28 error 4359425741253018.5
# Bi-cgstab did NOT converge for Dc. Error 1.7940818940564226e+16
# iteration 29 error 1.7307713165284424e+16
# Bi-cgstab did NOT converge for Dc. Error 4.185740239856351e+16
# iteration 30 error 3.84953808873549e+16
# Bi-cgstab did NOT converge for Dc. Error 5.307495589169525e+16
# iteration 31 error 4.256982896295914e+16
# Bi-cgstab did NOT converge for Dc. Error 2.9670556913719866e+17
# iteration 32 error 1.2744865708689288e+17
# Bi-cgstab did NOT converge for Dc. Error 4.052871932414563e+17
# iteration 33 error 3.9078641128506106e+17
# Bi-cgstab did NOT converge for Dc. Error 3.6268288458194964e+18
# iteration 34 error 2.1887032042066289e+18
# Bi-cgstab did NOT converge for Dc. Error 6.707218429856274e+18
# iteration 35 error 5.928044318920027e+18
# Bi-cgstab did NOT converge for Dc. Error 5.597347256758975e+18
# iteration 36 error 5.657487696505191e+18
# Bi-cgstab did NOT converge for Dc. Error 2.8678035117411766e+19
# iteration 37 error 2.260343881155342e+19
# Bi-cgstab did NOT converge for Dc. Error 7.863756302162549e+19
# iteration 38 error 6.0959162192371786e+19
# Bi-cgstab did NOT converge for Dc. Error 1.3655452909540455e+20
# iteration 39 error 1.261683911965422e+20
# Bi-cgstab did NOT converge for Dc. Error 2.333834342529885e+20
# iteration 40 error 2.4120026986211557e+20
# Bi-cgstab did NOT converge for Dc. Error 3.7385711630445747e+20
# iteration 41 error 3.86240690800523e+20
# Bi-cgstab did NOT converge for Dc. Error 1.6014201117181778e+21
# iteration 42 error 1.2731728843048427e+21
# Bi-cgstab did NOT converge for Dc. Error 6.2975779673535e+21
# iteration 43 error 5.047728735340572e+21
# Bi-cgstab did NOT converge for Dc. Error 8.611598546375443e+21
# iteration 44 error 8.216079183461998e+21
# Bi-cgstab did NOT converge for Dc. Error 2.481492784259846e+22
# iteration 45 error 1.941686435397972e+22
# Bi-cgstab did NOT converge for Dc. Error 3.1502011845465625e+22
# iteration 46 error 2.928071696033214e+22
# Bi-cgstab did NOT converge for Dc. Error 8.512683014768745e+22
# iteration 47 error 8.164514143213562e+22
# Bi-cgstab did NOT converge for Dc. Error 1.6325394264511687e+23
# iteration 48 error 1.392193556392095e+23
# Bi-cgstab did NOT converge for Dc. Error 4.1222056397539935e+23
# iteration 49 error 3.620647760778815e+23
# Bi-cgstab did NOT converge for Dc. Error 5.161142023679884e+23
# iteration 50 error 5.394209216115169e+23
# Bi-cgstab did NOT converge for Dc. Error 1.7751382024169488e+24
# iteration 51 error 1.4082447681558077e+24
# Bi-cgstab did NOT converge for Dc. Error 4.7862599931605414e+24
# iteration 52 error 3.867859556786264e+24
# Bi-cgstab did NOT converge for Dc. Error 1.1423533992176191e+25
# iteration 53 error 1.1214791800629773e+25
# Bi-cgstab did NOT converge for Dc. Error 1.7478119376337442e+25
# iteration 54 error 1.6841530295513123e+25
# Bi-cgstab did NOT converge for Dc. Error 8.193717414040909e+26
# iteration 55 error 5.038045355544875e+26
# Bi-cgstab did NOT converge for Dc. Error 1.598875722857121e+27
# iteration 56 error 1.4847290120932327e+27
# Bi-cgstab did NOT converge for Dc. Error 2.74336115801844e+27
# iteration 57 error 2.819490248306392e+27
# Bi-cgstab did NOT converge for Dc. Error 8.890051526509335e+27
# iteration 58 error 8.470896941032134e+27
# Bi-cgstab did NOT converge for Dc. Error 1.2272148820174219e+28
# iteration 59 error 1.2310969485000107e+28
# Bi-cgstab did NOT converge for Dc. Error 4.820510328497497e+28
# iteration 60 error 3.7706739034885192e+28
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 12
#      10 max_iter = 100
#      11 tol = 1e-10
# ---> 12 x_sol = amg.TwoGrid(max_iter,tol,x0,phi,True)
#
# Cell In[15], line 89, in AMG.TwoGrid(self, max_iter, tol, x0, phi, message)
#      86     #x = Kaczmarz(self.D,2*Ntot,phi,x,nu1,1e-10)
#      87 #Coarse grid correction
#      88 Pt_r = self.PH.dot( (phi-self.D.dot(x)))
# ---> 89 Dc_inv, exit_code = bicgstab(self.Dc, Pt_r,x0=Pt_r,maxiter=10000, rtol=1e-10, atol=0.0) #Dc^-1 P^H(phi-Dx)
#      90 if message==True:
#      91     if exit_code == 0:
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/linalg/_isolve/iterative.py:255, in bicgstab(A, b, x0, rtol, atol, maxiter, M, callback)
#     252     p = r.copy()
#     254 phat = psolve(p)
# --> 255 v = matvec(phat)
#     256 rv = dotprod(rtilde, v)
#     257 if rv == 0:
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/linalg/_interface.py:236, in LinearOperator.matvec(self, x)
#     233 if x.shape != (N,) and x.shape != (N,1):
#     234     raise ValueError('dimension mismatch')
# --> 236 y = self._matvec(x)
#     238 if isinstance(x, np.matrix):
#     239     y = asmatrix(y)
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/linalg/_interface.py:203, in LinearOperator._matvec(self, x)
#     193 def _matvec(self, x):
#     194     """Default matrix-vector multiplication handler.
#     195
#     196     If self is a linear operator of shape (M, N), then this method will
#    (...)
#     201     will define matrix-vector multiplication as well.
#     202     """
# --> 203     return self.matmat(x.reshape(-1, 1))
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/linalg/_interface.py:340, in LinearOperator.matmat(self, X)
#     337     raise ValueError(f'dimension mismatch: {self.shape}, {X.shape}')
#     339 try:
# --> 340     Y = self._matmat(X)
#     341 except Exception as e:
#     342     if issparse(X) or is_pydata_spmatrix(X):
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/linalg/_interface.py:800, in MatrixLinearOperator._matmat(self, X)
#     799 def _matmat(self, X):
# --> 800     return self.A.dot(X)
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/_base.py:450, in _spbase.dot(self, other)
#     448     return self * other
#     449 else:
# --> 450     return self @ other
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/_base.py:669, in _spbase.__matmul__(self, other)
#     666 if isscalarlike(other):
#     667     raise ValueError("Scalar operands are not allowed, "
#     668                      "use '*' instead")
# --> 669 return self._matmul_dispatch(other)
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/_base.py:566, in _spbase._matmul_dispatch(self, other)
#     564     return self._matmul_vector(other)
#     565 elif other.shape == (N, 1):
# --> 566     result = self._matmul_vector(other.ravel())
#     567     if self.ndim == 1:
#     568         return result
#
# File /usr/local/lib64/python3.11/site-packages/scipy/sparse/_compressed.py:492, in _cs_matrix._matmul_vector(self, other)
#     490 # csr_matvec or csc_matvec
#     491 fn = getattr(_sparsetools, self.format + '_matvec')
# --> 492 fn(M, N, self.indptr, self.indices, self.data, other, result)
#     494 return result[0] if self.ndim == 1 else result
#
# KeyboardInterrupt:

# %%
for i in range(2*Ntot):
    line_new = '{:>12} {:>12} {:>12}'.format(x_sol[i], x_bi[i], x_gmres[i])
    print(line_new)
# Out:
# (-0.008152376015691373-0.3946391487149849j) (-0.008152376034950988-0.39463914864440625j) (-0.008152376044794877-0.39463914865134325j)
# (0.36135284510198856-0.3347464925161191j) (0.36135284522901845-0.33474649258157j) (0.36135284518919886-0.3347464925855151j)
# (-0.18425237609652198+0.03858312851417416j) (-0.1842523760715103+0.03858312847635965j) (-0.18425237607743417+0.038583128486278866j)
# (-0.27698957940025426+0.2903123445242064j) (-0.27698957936994106+0.290312344605406j) (-0.2769895793705123+0.29031234460921934j)
# (-0.09618485712973739-0.11621005762308721j) (-0.09618485721623085-0.1162100576979343j) (-0.09618485721018653-0.11621005769003691j)
# (-0.3117317554225217-0.2412645231971231j) (-0.31173175540391623-0.2412645231592616j) (-0.31173175543018405-0.2412645231969394j)
# (-0.08866725184103366+0.09447128499321579j) (-0.08866725185619108+0.09447128484931322j) (-0.08866725183434644+0.09447128483113308j)
# (-0.03151863698765234-0.4701925977261856j) (-0.031518636960209824-0.47019259771770505j) (-0.03151863697276139-0.4701925977198343j)
# (-0.3232655570239997-0.11351584473485445j) (-0.3232655572210571-0.11351584474558934j) (-0.32326555718305566-0.11351584472984672j)
# (0.094536837649466-0.27109934415624437j) (0.09453683756415932-0.27109934422418563j) (0.094536837590879-0.27109934421435233j)
# (0.31856902087551997+0.2220370924075174j) (0.3185690206797774+0.22203709229267346j) (0.31856902070555554+0.222037092311939j)
# (-0.03560416465676502-0.4426518996128762j) (-0.035604164719497795-0.44265189975385705j) (-0.03560416470414694-0.4426518997636863j)
# (0.282571490985912-0.17835375413925555j) (0.28257149085348393-0.17835375405970696j) (0.28257149088885003-0.1783537540654855j)
# (-0.2908434162605897-0.08354319031473996j) (-0.2908434165132526-0.08354319027987178j) (-0.2908434164644164-0.08354319028540737j)
# (-0.4196696844172115-0.06893414741570646j) (-0.4196696843029291-0.06893414736650708j) (-0.41966968429155294-0.06893414735858595j)
# (-0.2877497119859735+0.32553992196615045j) (-0.2877497118246178+0.325539922058968j) (-0.28774971182098547+0.3255399220862595j)
# (0.10776658477390355-0.2638706914550758j) (0.10776658488769962-0.2638706914499537j) (0.10776658486728932-0.2638706914274098j)
# (-0.17533812902288035+0.06645574297898672j) (-0.17533812910448415+0.06645574294204433j) (-0.17533812906129911+0.06645574294626537j)
# (0.06537699794477143-0.35940510088710614j) (0.06537699796555206-0.35940510081743104j) (0.06537699797232671-0.35940510086184246j)
# (0.08429429268769208+0.312027220733118j) (0.08429429266059205+0.31202722060670995j) (0.08429429268019112+0.3120272207066944j)
# (0.2131446212622354-0.09184624586122206j) (0.21314462121122735-0.09184624584451606j) (0.21314462122052305-0.09184624590628661j)
# (0.039847462776355994+0.202711995246305j) (0.03984746282863983+0.2027119951372121j) (0.03984746284067071+0.20271199516294788j)
# (0.011745369088484356+0.36172546680462786j) (0.011745369019153837+0.36172546680991313j) (0.011745369020291177+0.36172546674210104j)
# (-0.11802526139801058+0.09498961950167421j) (-0.11802526133759918+0.09498961947100261j) (-0.11802526139202303+0.0949896194805021j)
# (-0.38743512158017046-0.005150487627645543j) (-0.38743512157907667-0.005150487658456969j) (-0.38743512154289717-0.00515048761881055j)
# (0.31535935221013783+0.052113426836870334j) (0.31535935208776605+0.052113426885643556j) (0.31535935213596644+0.05211342681259152j)
# (-0.19617143072513046-0.3666180152506437j) (-0.19617143060948375-0.3666180153025993j) (-0.19617143066874806-0.36661801526991805j)
# (-0.06671273160267986+0.5615791044525787j) (-0.06671273173786262+0.5615791043863007j) (-0.06671273167334492+0.5615791043628353j)
# (-0.2914344437625419+0.2556558336318612j) (-0.29143444393246787+0.25565583359490246j) (-0.2914344439211307+0.2556558335663278j)
# (0.09975998360567016-0.5281454045388577j) (0.09975998361213896-0.5281454044440601j) (0.09975998357832624-0.5281454044310607j)
# (-0.09590475799183465+0.34293193777236786j) (-0.09590475818625814+0.34293193791861437j) (-0.09590475815884475+0.34293193787664367j)
# (0.03292811831132207-0.3271814953798601j) (0.032928118355735954-0.32718149528545487j) (0.03292811832762373-0.32718149531648905j)

# %% [markdown]
# ### Some tests for a two-grid method using GRMES as smoother

# %%
dim = Nx*Nt*2
D = np.zeros((dim,dim),dtype=complex)
phi = np.zeros(dim,dtype=complex)
x0 = np.zeros(2*Ntot,dtype=complex)
iterations = []
for conf in range(50):
    row, col, re, im = DatosMat("build/D{0}.dat".format(conf))
    for i in range(dim*dim):
        D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
    row, col, re, im = DatosMat("build/Phi{0}.dat".format(conf))
    for i in range(dim):
        phi[i] = re[i] + 1j*im[i] 
    for i in range(2*Ntot):  
        theta = np.random.uniform(0,2*pi)
        x0[i] = np.cos(theta) + 1j*np.sin(theta)
    nu1, nu2 = 0, 2
    Nit = 5
    print("Conf #{0}".format(conf))
    amg = AMG(D,nu1,nu2)
    amg.tv(Nit)
    P, PH = amg.get_p()
    max_iter = 100
    tol = 1e-10
    x_sol = amg.TwoGrid(max_iter,tol,x0,phi,False)
    iterations.append(amg.get_iterations())
iterations = np.array(iterations)
print("Number of iterations: {0} +- {1}".format(np.round(np.mean(iterations),4), np.round(np.std(iterations)/np.sqrt(50),4  ) ))
# Out:
# Conf #0
# Improving interpolator
# n=0 out of Nit=5
# two-grid converged in 1 iterations. Error  7.511382602998564e-10
# two-grid converged in 1 iterations. Error  4.1980928106995065e-10
# two-grid converged in 1 iterations. Error  4.364873102195447e-10
# two-grid converged in 1 iterations. Error  4.3842977113104227e-10
# two-grid converged in 1 iterations. Error  4.027196194574091e-10
# two-grid converged in 1 iterations. Error  4.5473205637633904e-10
# two-grid converged in 1 iterations. Error  7.548572046261018e-10
# two-grid converged in 1 iterations. Error  3.7143775127820453e-10
# two-grid converged in 1 iterations. Error  7.777577775749855e-10
# two-grid converged in 1 iterations. Error  3.845861746491433e-10
# two-grid converged in 1 iterations. Error  4.581001916464786e-10
# two-grid converged in 1 iterations. Error  7.589366139292917e-10
# two-grid converged in 1 iterations. Error  3.811706130783146e-10
# two-grid converged in 1 iterations. Error  3.717097482921278e-10
# two-grid converged in 1 iterations. Error  4.121605706841891e-10
# two-grid converged in 1 iterations. Error  4.553497055435891e-10
# two-grid converged in 1 iterations. Error  4.1719525967605373e-10
# two-grid converged in 1 iterations. Error  4.1947205596310154e-10
# two-grid converged in 1 iterations. Error  4.4491696646305707e-10
# two-grid converged in 1 iterations. Error  3.980300131396552e-10
# two-grid converged in 1 iterations. Error  4.094085875578428e-10
# two-grid converged in 1 iterations. Error  4.742314340449359e-10
# two-grid converged in 1 iterations. Error  4.459426606829907e-10
# two-grid converged in 1 iterations. Error  7.620879373816669e-10
# two-grid converged in 1 iterations. Error  4.312818044866687e-10
# n=1 out of Nit=5
# two-grid converged in 1 iterations. Error  1.7405654671585725e-10
# two-grid converged in 1 iterations. Error  2.018490668963651e-10
# two-grid converged in 1 iterations. Error  1.0830723287247218e-10
# two-grid converged in 1 iterations. Error  2.0715336157690143e-10
# two-grid converged in 1 iterations. Error  1.982507259301968e-10
# two-grid converged in 1 iterations. Error  1.0314086386030582e-10
# two-grid converged in 1 iterations. Error  1.6893020131548977e-10
# two-grid converged in 1 iterations. Error  1.7960530372008585e-10
# two-grid converged in 1 iterations. Error  1.7965931336794593e-10
# two-grid converged in 1 iterations. Error  1.8677296098460711e-10
# two-grid converged in 1 iterations. Error  1.0630595686546486e-10
# two-grid converged in 1 iterations. Error  1.7398190008076544e-10
# two-grid converged in 1 iterations. Error  1.8795912807776847e-10
# two-grid converged in 1 iterations. Error  1.7875396818232358e-10
# two-grid converged in 1 iterations. Error  1.9878894358371996e-10
# two-grid converged in 1 iterations. Error  1.1172060938353541e-10
# two-grid converged in 1 iterations. Error  2.0220767965418802e-10
# two-grid converged in 1 iterations. Error  2.145767423959322e-10
# two-grid converged in 1 iterations. Error  2.206284197794746e-10
# two-grid converged in 1 iterations. Error  1.9229477541395492e-10
# two-grid converged in 1 iterations. Error  2.0321672456179767e-10
# two-grid converged in 1 iterations. Error  1.0649184391540517e-10
# two-grid converged in 1 iterations. Error  2.0935706252198861e-10
# two-grid converged in 1 iterations. Error  1.7549117084078995e-10
# two-grid converged in 1 iterations. Error  2.0963970124932013e-10
# n=2 out of Nit=5
# two-grid converged in 1 iterations. Error  4.413704733324173e-11
# two-grid converged in 1 iterations. Error  5.1600722254566e-11
# two-grid converged in 1 iterations. Error  5.801570768338399e-11
# two-grid converged in 1 iterations. Error  5.026950770141163e-11
# two-grid converged in 1 iterations. Error  5.030991305843014e-11
# two-grid converged in 1 iterations. Error  5.3723974056915826e-11
# two-grid converged in 1 iterations. Error  4.070495664485881e-11
# two-grid converged in 1 iterations. Error  4.5395297985369624e-11
# two-grid converged in 1 iterations. Error  4.5856902609351166e-11
# two-grid converged in 1 iterations. Error  4.621737946789049e-11
# two-grid converged in 1 iterations. Error  5.710951398182583e-11
# two-grid converged in 1 iterations. Error  4.413451652410672e-11
# two-grid converged in 1 iterations. Error  4.8852791280257606e-11
# two-grid converged in 1 iterations. Error  4.5922771259289274e-11
# two-grid converged in 1 iterations. Error  4.886761785085296e-11
# two-grid converged in 1 iterations. Error  5.993744116028963e-11
# two-grid converged in 1 iterations. Error  5.2039063864844935e-11
# two-grid converged in 1 iterations. Error  5.514972101391474e-11
# two-grid converged in 1 iterations. Error  5.5612829790165e-11
# two-grid converged in 1 iterations. Error  4.780645184112171e-11
# two-grid converged in 1 iterations. Error  5.2257225570694397e-11
# two-grid converged in 1 iterations. Error  5.748067711898856e-11
# two-grid converged in 1 iterations. Error  5.423689463636161e-11
# two-grid converged in 1 iterations. Error  4.42421203874755e-11
# two-grid converged in 1 iterations. Error  5.398228676575732e-11
# n=3 out of Nit=5
# two-grid converged in 1 iterations. Error  1.2456710340343843e-11
# two-grid converged in 1 iterations. Error  1.4823336987347876e-11
# two-grid converged in 1 iterations. Error  1.4847518357942924e-11
# two-grid converged in 1 iterations. Error  1.3578171182190048e-11
# two-grid converged in 1 iterations. Error  1.3954923523769007e-11
# two-grid converged in 1 iterations. Error  1.458877704135155e-11
# two-grid converged in 1 iterations. Error  2.2996101348187148e-11
# two-grid converged in 1 iterations. Error  2.555654172460552e-11
# two-grid converged in 1 iterations. Error  1.2974100736319108e-11
# two-grid converged in 1 iterations. Error  2.6359989165937452e-11
# two-grid converged in 1 iterations. Error  1.54882830365859e-11
# two-grid converged in 1 iterations. Error  2.6237649417063842e-11
# two-grid converged in 1 iterations. Error  1.304553291148048e-11
# two-grid converged in 1 iterations. Error  2.662309388460937e-11
# two-grid converged in 1 iterations. Error  2.785889308531451e-11
# two-grid converged in 1 iterations. Error  1.5883573323160045e-11
# two-grid converged in 1 iterations. Error  1.3900190757776644e-11
# two-grid converged in 1 iterations. Error  1.483497738304488e-11
# two-grid converged in 1 iterations. Error  1.4712745403637024e-11
# two-grid converged in 1 iterations. Error  1.2819882914620706e-11
# two-grid converged in 1 iterations. Error  1.4130082909195077e-11
# two-grid converged in 1 iterations. Error  1.5957935019503797e-11
# two-grid converged in 1 iterations. Error  1.499752810896906e-11
# two-grid converged in 1 iterations. Error  1.1965693837496893e-11
# two-grid converged in 1 iterations. Error  1.5270838415337362e-11
# n=4 out of Nit=5
# two-grid converged in 1 iterations. Error  7.524739247154777e-12
# two-grid converged in 1 iterations. Error  8.789234058848513e-12
# two-grid converged in 1 iterations. Error  8.940970116480111e-12
# two-grid converged in 1 iterations. Error  8.265133876048612e-12
# two-grid converged in 1 iterations. Error  8.563443512416008e-12
# two-grid converged in 1 iterations. Error  8.321007320702497e-12
# two-grid converged in 1 iterations. Error  6.5918782813054445e-12
# two-grid converged in 1 iterations. Error  7.18981066044299e-12
# two-grid converged in 1 iterations. Error  8.091902145778116e-12
# two-grid converged in 1 iterations. Error  7.608824122477833e-12
# two-grid converged in 1 iterations. Error  9.549767219660356e-12
# two-grid converged in 1 iterations. Error  7.744848889511398e-12
# two-grid converged in 1 iterations. Error  8.025183784835205e-12
# two-grid converged in 1 iterations. Error  7.872274114857734e-12
# two-grid converged in 1 iterations. Error  7.959916970482596e-12
# two-grid converged in 1 iterations. Error  9.833567661583467e-12
# two-grid converged in 1 iterations. Error  8.293352483380589e-12
# two-grid converged in 1 iterations. Error  8.968787920897977e-12
# two-grid converged in 1 iterations. Error  8.941511829139475e-12
# two-grid converged in 1 iterations. Error  7.695911372292904e-12
# two-grid converged in 1 iterations. Error  8.691689214825935e-12
# two-grid converged in 1 iterations. Error  4.752047023452364e-12
# two-grid converged in 1 iterations. Error  9.17546776363126e-12
# two-grid converged in 1 iterations. Error  7.331218195471605e-12
# two-grid converged in 1 iterations. Error  9.096770951897066e-12
# two-grid converged in 1 iterations. Error  3.762983098771781e-09
# Conf #1
# Improving interpolator
# n=0 out of Nit=5
# two-grid converged in 1 iterations. Error  4.932298739044602e-10
# two-grid converged in 1 iterations. Error  5.089668746912438e-10
# two-grid converged in 1 iterations. Error  4.670297075724725e-10
# two-grid converged in 1 iterations. Error  4.3340557734259906e-10
# two-grid converged in 1 iterations. Error  4.789400245124939e-10
# two-grid converged in 1 iterations. Error  4.3581445247126375e-10
# two-grid converged in 1 iterations. Error  4.690888814388601e-10
# two-grid converged in 1 iterations. Error  4.61612900806037e-10
# two-grid converged in 1 iterations. Error  4.378995741448511e-10
# two-grid converged in 1 iterations. Error  4.911958381913225e-10
# two-grid converged in 1 iterations. Error  4.888418326233409e-10
# two-grid converged in 1 iterations. Error  4.73609232108756e-10
# two-grid converged in 1 iterations. Error  4.645981309368746e-10
# two-grid converged in 1 iterations. Error  4.4664697571031366e-10
# two-grid converged in 1 iterations. Error  4.5364557605512865e-10
# two-grid converged in 1 iterations. Error  4.731891540106646e-10
# two-grid converged in 1 iterations. Error  4.060328933782802e-10
# two-grid converged in 1 iterations. Error  4.385987254502431e-10
# two-grid converged in 1 iterations. Error  4.600424267901304e-10
# two-grid converged in 1 iterations. Error  4.5056861941840696e-10
# two-grid converged in 1 iterations. Error  4.2074911909364293e-10
# two-grid converged in 1 iterations. Error  4.676635814039273e-10
# two-grid converged in 1 iterations. Error  4.637257424244898e-10
# two-grid converged in 1 iterations. Error  4.520844007898392e-10
# two-grid converged in 1 iterations. Error  4.403399164937708e-10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 20
#      18 print("Conf #{0}".format(conf))
#      19 amg = AMG(D,nu1,nu2)
# ---> 20 amg.tv(Nit)
#      21 P, PH = amg.get_p()
#      22 max_iter = 100
#
# Cell In[5], line 56, in AMG.tv(self, Nit)
#      54 for i in range(Ntest):
#      55     self.test_vectors[i] = self.TwoGrid(1,1e-10,self.test_vectors[i],self.test_vectors[i],False)
# ---> 56 self.P_v() #Assemble P
#      57 self.orthonormalize()
#
# Cell In[5], line 70, in AMG.P_v(self)
#      68         for i in range(len(Agg[a])):
#      69             x, t, s = XCoord[Agg[a,i]], TCoord[Agg[a,i]], SCoord[Agg[a,i]]
# ---> 70             P_v[Coords[x,t,s]]  += self.test_vectors[k,Coords[x,t,s]] * v[j]
#      71     self.P[:,can_vec] = P_v
#      72 self.PH = csc_array(np.conjugate(np.transpose(self.P)))
#
# KeyboardInterrupt:

# %% [markdown]
# ### Tests using GMRES

# %%
dim = Nx*Nt*2
D = np.zeros((dim,dim),dtype=complex)
phi = np.zeros(dim,dtype=complex)
x0 = np.zeros(2*Ntot,dtype=complex)
tol = 1e-10
iterations = []
for conf in range(8):
    row, col, re, im = DatosMat("build/D{0}.dat".format(conf))
    for i in range(dim*dim):
        D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
    row, col, re, im = DatosMat("build/Phi{0}.dat".format(conf))
    for i in range(dim):
        phi[i] = re[i] + 1j*im[i] 
    for i in range(2*Ntot):  
        theta = np.random.uniform(0,2*pi)
        x0[i] = np.cos(theta) + 1j*np.sin(theta)
    Dsparse = csc_array(D)
    x_gmres = x0
    #GMRES
    print("Conf #{0}".format(conf))
    max_err = tol*np.linalg.norm(phi)
    err = 1
    k = 0
    while k<1000 and err>max_err:
        x_gmres, exit_code = gmres(Dsparse, phi, x0=x_gmres, rtol=1e-10, atol=0.0, maxiter=1)
        r = phi - Dsparse.dot(x_gmres)
        err = np.sqrt(np.real(np.vdot(r,r)))
        if err<=max_err:
            print("GMRES converged in {0} iterations".format(k+1))
            iterations.append([k+1])
        k += 1
iterations = np.array(iterations)
print("Number of iterations: {0} +- {1}".format(np.round(np.mean(iterations),4), np.round(np.std(iterations)/np.sqrt(50),4  ) ))

# %% [markdown]
# ### Testing Kaczmarz as a solver

# %%
dim = Nx*Nt*2
print(dim)
D = np.zeros((dim,dim),dtype=complex)
row, col, re, im = DatosMat("build/D0.dat")
for i in range(dim*dim):
    D[ int(row[i]), int(col[i]) ] = re[i] + 1j*im[i] 
phi = np.zeros(dim,dtype=complex)
row, col, re, im = DatosMat("build/Phi0.dat")
for i in range(dim):
    phi[i] = re[i] + 1j*im[i] 

#Initial solution
x0 = np.zeros(2*Ntot,dtype=complex)
for i in range(2*Ntot):  
    theta = np.random.uniform(0,2*pi)
    x0[i] = np.cos(theta) + 1j*np.sin(theta)

Dsparse = csc_array(D)
tol = 1e-10
max_iter = 500
x = deepcopy(x0)
for i in range(max_iter):
    x = Kaczmarz(D,2*Ntot,phi,x,1,1e-10)
    r = phi - Dsparse.dot(x)
    err = np.sqrt(np.real( np.vdot(r,r) ))
    print(err)
    if err<=tol:
        print("Kaczmarz converged in {0} iterations".format(i+1))
        break
print(x[0])
#x = deepcopy(x0)
#x=Kaczmarz(D,2*Ntot,phi,x,5,1e-10)
#print(x[0])
