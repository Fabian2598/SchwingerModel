# %% [markdown]
# # $m_\pi$ and $m_{\mathrm{PCAC}}$ analysis
#
# Program for measuring the pion and PCAC mass given the correlators  $$c(n_t):=\frac{1}{\sqrt{x}}\sum_x \langle \mathcal{O}_\pi(x,t) \overline{\mathcal{O}}_\pi(0,0)\rangle=-\sum_x\sum_{\alpha,\beta=0}^1 |D^{-1}(x,t|0,0)_{\alpha,\beta}|^2.$$
#
# $$m_{\mathrm{PCAC}}(t) = \frac{C_{\mathrm{AP}}(t+1)-C_{\mathrm{AP}}(t-1)}{4 C_{\mathrm{PP}}(t)}$$
# $$C_{\mathrm{PP}}(t) = -\frac{1}{2 \sqrt{N_x}} \sum_x \sum_{\alpha,\beta=0}^1 |D^{-1}(x,t|0,0)_{\alpha,\beta}|^2$$
# $$C_{\mathrm{AP}}(t) = -\frac{1}{2 \sqrt{N_x}} \sum_x \mathrm{Tr}\left[\gamma_0 \gamma_5 D^{-1}(x,t|0,0) \gamma_5 D^{-1}(0,0|x,t)\right]$$

# %%
import numpy as np
from functions import *

# %%
#Plot correlation function for the pion
beta, Nx, Nt = 4, 64, 64
obs = "pion"
masses = [kappa2mass(0.259),kappa2mass(0.255),kappa2mass(0.253),kappa2mass(0.252),kappa2mass(0.251),kappa2mass(0.248),kappa2mass(0.247)]
mean_ranges = [10,25]
correlator_dir = "../build/confs_temp/b{0}_{1}x{2}/correlators/".format(beta,Nx,Nt)
#correlator_dir = "/wsgjsc/home/nietocastellanos1/Documents/SchwingerModel/fermions/SchwingerModel/confs/b4_64x64/"
plot_correlators(correlator_dir,obs,masses,beta,Nx,Nt,save=False)
#print_correlator(correlator_dir,masses[0],beta,Nx,Nt)
plot_effective_mass(correlator_dir,masses,beta,Nx,Nt,mean_ranges,save=False)
# Out:
# m0 = -0.0695, kappa = 0.259, mpi = 0.1647 +- 0.0162
# m0 = -0.03922, kappa = 0.255, mpi = 0.2488 +- 0.0199
# m0 = -0.02372, kappa = 0.253, mpi = 0.2864 +- 0.0159
# m0 = -0.01587, kappa = 0.252, mpi = 0.3101 +- 0.0141
# m0 = -0.00797, kappa = 0.251, mpi = 0.3308 +- 0.014
# m0 = 0.01613, kappa = 0.248, mpi = 0.3824 +- 0.0083
# m0 = 0.02429, kappa = 0.247, mpi = 0.3981 +- 0.0086

# %%
#Plot PCAC mass
beta, Nx, Nt = 4, 64, 64
obs = "pcac"
masses = [kappa2mass(0.259),kappa2mass(0.255),kappa2mass(0.253),kappa2mass(0.252),kappa2mass(0.251),kappa2mass(0.248),kappa2mass(0.247)]
#masses = [kappa2mass(0.255)]
mean_ranges = [10,25]
correlator_dir = "../build/confs_temp/b{0}_{1}x{2}/correlators/".format(beta,Nx,Nt)
plot_correlators(correlator_dir,obs,masses,beta,Nx,Nt,save=False)

# %%
mpi_vs_mpcac(correlator_dir,masses,beta,Nx,Nt,mean_ranges,save=False)
# Out:
# mpcac = 0.0313 +- 0.0003
# mpcac = 0.0618 +- 0.0004
# mpcac = 0.0767 +- 0.0004
# mpcac = 0.0851 +- 0.0003
# mpcac = 0.0933 +- 0.0002
# mpcac = 0.1165 +- 0.0003
# mpcac = 0.1241 +- 0.0003

# %%
kappa2mass(0.253)
# Out:
# -0.02371541501976293
